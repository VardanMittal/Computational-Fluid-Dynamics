# %%
import numpy as np
import os, sys
sys.path.append(os.path.abspath(os.path.join('../..')))

# %%
from utils.solvers import GaussElimination

# %%
n = 100 # No of nodes
q= 1e6
k = 0.5
Delta_x = 0.02 / n
T1 = 100
T7 = 200

# %%
b = np.zeros(n)
A = np.zeros((n,n))

# %%
for i in range(1, n-1):
    b[i] = (-q * (Delta_x**2))/k
b[0] = T1 + (-q * (Delta_x**2))/k
b[n-1] = T7 + (-q * (Delta_x**2))/k

# %%
for i in range(n-1):
    A[i][i] = -2
    A[i][i+1] = 1
    A[i+1][i] = 1

A[n-1][n-1] = -2

# %%
x =GaussElimination(A,b)

# %%
print(A)
# Out:
# [[-2.          1.          0.         ...  0.          0.
#    0.        ]
#  [ 0.         -1.5         1.         ...  0.          0.
#    0.        ]
#  [ 0.          0.         -1.33333333 ...  0.          0.
#    0.        ]
#  ...
#  [ 0.          0.          0.         ... -1.01020408  1.
#    0.        ]
#  [ 0.          0.          0.         ...  0.         -1.01010101
#    1.        ]
#  [ 0.          0.          0.         ...  0.          0.
#   -1.01      ]]

# %%
b
# Out:
# array([ 9.99200000e+01,  4.98800000e+01,  3.31733333e+01,  2.48000000e+01,
#         1.97600000e+01,  1.63866667e+01,  1.39657143e+01,  1.21400000e+01,
#         1.07111111e+01,  9.56000000e+00,  8.61090909e+00,  7.81333333e+00,
#         7.13230769e+00,  6.54285714e+00,  6.02666667e+00,  5.57000000e+00,
#         5.16235294e+00,  4.79555556e+00,  4.46315789e+00,  4.16000000e+00,
#         3.88190476e+00,  3.62545455e+00,  3.38782609e+00,  3.16666667e+00,
#         2.96000000e+00,  2.76615385e+00,  2.58370370e+00,  2.41142857e+00,
#         2.24827586e+00,  2.09333333e+00,  1.94580645e+00,  1.80500000e+00,
#         1.67030303e+00,  1.54117647e+00,  1.41714286e+00,  1.29777778e+00,
#         1.18270270e+00,  1.07157895e+00,  9.64102564e-01,  8.60000000e-01,
#         7.59024390e-01,  6.60952381e-01,  5.65581395e-01,  4.72727273e-01,
#         3.82222222e-01,  2.93913043e-01,  2.07659574e-01,  1.23333333e-01,
#         4.08163265e-02, -4.00000000e-02, -1.19215686e-01, -1.96923077e-01,
#        -2.73207547e-01, -3.48148148e-01, -4.21818182e-01, -4.94285714e-01,
#        -5.65614035e-01, -6.35862069e-01, -7.05084746e-01, -7.73333333e-01,
#        -8.40655738e-01, -9.07096774e-01, -9.72698413e-01, -1.03750000e+00,
#        -1.10153846e+00, -1.16484848e+00, -1.22746269e+00, -1.28941176e+00,
